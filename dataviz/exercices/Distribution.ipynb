# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

df = pd.read_csv('../data/IBM_HR_ATTRITION.csv')

# %%
sns.distplot(df['MonthlyIncome'], kde=False)

# %%
wo_high_incomes_df = df.loc[(df['MonthlyIncome'] >= 0) & (df['MonthlyIncome'] <= 5000)]
sns.distplot(wo_high_incomes_df['MonthlyIncome'], kde=False)
